# %% [markdown]
# **Performing matrix multiplication and finding eigen vectors and eigen values using TensorFlow**

# %% [markdown]
# How to compute the eigenvalues and right eigenvectors of a given square array using NumPy library.

# %%
import tensorflow as tf

m = tf.constant([[1, 2], [2, 3]], dtype=tf.float32)
eigenvalues, eigenvectors = tf.linalg.eig(m)
print(eigenvalues.numpy())
print(eigenvectors.numpy())

import numpy as np
m = np.array([[1, 2],
			[2, 3]])
print("Printing the Original square array:\n",m)
w, v = np.linalg.eig(m)
print("Printing the Eigen values of the given square array:\n",w)
print("Printing Right Eigen Vectors of the given square array:\n",v)

import numpy as np
m = np.array([[1, 2, 3],
			[2, 3, 4],
			[4, 5, 6]])

print("Printing the Original square array:\n",m)
w, v = np.linalg.eig(m)

print("Eigen values of the given square array:\n",w)
print("Eigenvectors of the given square array:\n",v)

# !pip install tensorflow
# !pip install tensorflow[and-cuda]

import tensorflow as tf
e_matrix_A = tf.random.uniform([2, 2], minval=3, maxval=10, dtype=tf.float32, name="matrixA")
print("Matrix A: \n{}\n\n".format(e_matrix_A))

eigen_values_A, eigen_vectors_A = tf.linalg.eigh(e_matrix_A)
print("Eigen Vectors: \n{} \n\nEigen Values: \n{}\n".format(eigen_vectors_A, eigen_values_A))

e_matrix_A = tf.random.uniform([3, 3], minval=3, maxval=10, dtype=tf.float32, name="matrixA")
print("Matrix A: \n{}\n\n".format(e_matrix_A))

eigen_values_A, eigen_vectors_A = tf.linalg.eigh(e_matrix_A)
print("Eigen Vectors: \n{} \n\nEigen Values: \n{}\n".format(eigen_vectors_A, eigen_values_A))
# Out:
# [-0.23606804+0.j  4.2360687 +0.j]
# [[-0.85065085+0.j -0.52573115+0.j]
#  [ 0.52573115+0.j -0.85065085+0.j]]
# Printing the Original square array:
#  [[1 2]
#  [2 3]]
# Printing the Eigen values of the given square array:
#  [-0.23606798  4.23606798]
# Printing Right Eigen Vectors of the given square array:
#  [[-0.85065081 -0.52573111]
#  [ 0.52573111 -0.85065081]]
# Printing the Original square array:
#  [[1 2 3]
#  [2 3 4]
#  [4 5 6]]
# Eigen values of the given square array:
#  [ 1.08309519e+01 -8.30951895e-01  1.01486082e-16]
# Eigenvectors of the given square array:
#  [[ 0.34416959  0.72770285  0.40824829]
#  [ 0.49532111  0.27580256 -0.81649658]
#  [ 0.79762415 -0.62799801  0.40824829]]
# Requirement already satisfied: tensorflow in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (2.13.1)
# Requirement already satisfied: tensorflow-intel==2.13.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.1->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from packaging->tensorflow-intel==2.13.1->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow) (3.2.2)
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow[and-cuda] in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (2.13.1)
# Requirement already satisfied: tensorflow-intel==2.13.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow[and-cuda]) (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.3.0)
# Requirement already satisfied: packaging in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (1.62.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow[and-cuda]) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from packaging->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow[and-cuda]) (3.2.2)
# Matrix A:
# [[5.9354944 9.729846 ]
#  [7.3089914 7.9980493]]
#
#
# Eigen Vectors:
# [[-0.75488853 -0.6558532 ]
#  [ 0.6558532  -0.75488853]]
#
# Eigen Values:
# [-0.41461667 14.348162  ]
#
# Matrix A:
# [[3.2782717 6.0768814 9.044252 ]
#  [3.9456491 3.2467813 8.0695305]
#  [5.468708  6.206593  5.816544 ]]
#
#
# Eigen Vectors:
# [[ 0.23254536 -0.83144706  0.50459737]
#  [ 0.67080504  0.5127833   0.53579295]
#  [-0.7042323   0.21389031  0.6769844 ]]
#
# Eigen Values:
# [-1.9012728  -0.56198007 14.804855  ]
# WARNING: tensorflow 2.13.1 does not provide the extra 'and-cuda'
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
